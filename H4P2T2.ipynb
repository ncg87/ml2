# %% [markdown]
# ### Build a DNN for ECG Signal Classification (5 classes)  - Pytorch
# This is the implementation of an MLP for classifying the ECG signals. <br>
# Your task is to design new DNNs for ECG signal classification <br>
# You can use this file as a template

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as nnF
from torch.utils.data import DataLoader as torch_dataloader
from torch.utils.data import Dataset as torch_dataset
import torch.optim as optim

# %% [markdown]
# ## The Neural Network: MLP  (Replace this with your MLP/CNN and rename the file)

# %%
class CNN(nn.Module):
    def __init__(self, input_size=187, num_classes=5):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv1d(1, 64, kernel_size=2, padding=0, stride = 2),
            nn.ReLU()
        )
        self.conv2 = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=2, padding=0, stride = 2),
            nn.ReLU()
        )
        
        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        self.norm3 = nn.BatchNorm1d(64)
        self.conv3 = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=2, padding=0, stride = 2),
            nn.ReLU()
        )
        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        self.norm4 = nn.BatchNorm1d(64)
        self.conv4 = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=2, padding=0, stride = 2),
            nn.ReLU()
        )
        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)
        self.norm5 = nn.BatchNorm1d(64)
        self.conv5 = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=2, padding=0, stride = 2),
            nn.ReLU()
        )
        
        feature_size = 5 * 64
        
        self.fc1 = nn.Sequential(
            nn.Linear(feature_size, 1024),
            nn.ReLU()
        )
        self.fc2 = nn.Linear(1024, num_classes)
        
    def forward(self, x):
        x1 = self.conv1(x)
        x1a = self.pool1(x1)
        
        x2c = self.conv2(x1)
        x2 = x2c + x1a
        x2a = self.pool2(x2)
        
        x3c = self.conv3(self.norm3(x2))
        x3 = x3c + x2a
        x3a = self.pool3(x3)
        
        x4c = self.conv4(self.norm4(x3))
        x4 = x4c + x3a
        
        x5 = self.conv5(self.norm5(x4))
        
        x5r = x5.view(x5.size(0), -1)
        
        x6 = self.fc1(x5r)
        z = self.fc2(x6)
        
        return z

# %%
#debug your network here
#make sure it works 
model=CNN()
x=torch.rand(10,1,187)
#x=torch.rand(10,1,187) if network is CNN
z=model(x)

# %%
def save_checkpoint(filename, model, optimizer, result, epoch):
    torch.save({'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'result':result},
               filename)
    print('saved:', filename)

# %%
def cal_accuracy(confusion):
    #input: confusion is the confusion matrix
    #output: acc is the standard classification accuracy
    M=confusion.copy().astype('float32')
    acc = M.diagonal().sum()/M.sum()    
    sens=np.zeros(M.shape[0])
    prec=np.zeros(M.shape[0]) 
    for n in range(0, M.shape[0]):
        TP=M[n,n]
        FN=np.sum(M[n,:])-TP
        FP=np.sum(M[:,n])-TP
        sens[n]=TP/(TP+FN)
        prec[n]=TP/(TP+FP)       
    return acc, sens, prec

# %% [markdown]
# ## The function to train the model

# %%
def train(model, device, optimizer, dataloader, epoch):    
    model.train()#set model to training mode
    loss_train=0
    acc_train =0 
    sample_count=0
    for batch_idx, (X, Y) in enumerate(dataloader):
        X, Y = X.to(device), Y.to(device)
        optimizer.zero_grad()#clear grad of each parameter
        Z = model(X)#forward pass
        loss = nnF.cross_entropy(Z, Y)
        loss.backward()#backward pass
        optimizer.step()#update parameters
        loss_train+=loss.item()
        #do not need softmax
        Yp = Z.data.max(dim=1)[1]  # get the index of the max               
        acc_train+= torch.sum(Yp==Y).item()
        sample_count+=X.size(0)
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{:.0f}%]\tLoss: {:.6f}'.format(
                    epoch, 100. * batch_idx / len(dataloader), loss.item()))
    loss_train/=len(dataloader)
    #due to upsampling, len(dataloader.dataset) != sample_count
    #acc_train/=len(dataloader.dataset) 
    acc_train/=sample_count    
    return loss_train, acc_train

# %% [markdown]
# ## The Function to test the model

# %%
def test(model, device, dataloader):
    model.eval()#set model to evaluation mode
    acc_test =0
    confusion=np.zeros((5,5))
    with torch.no_grad(): # tell Pytorch not to build graph in the with section
        for batch_idx, (X, Y) in enumerate(dataloader):
            X, Y = X.to(device), Y.to(device)
            Z = model(X)#forward pass
            #do not need softmax
            Yp = Z.data.max(dim=1)[1]  # get the index of the max 
            acc_test+= torch.sum(Yp==Y).item()
            for i in range(0, 5):
                for j in range(0, 5):
                    confusion[i,j]+=torch.sum((Y==i)&(Yp==j)).item()
    acc, sens, prec=cal_accuracy(confusion)
    return acc, (confusion, sens, prec)

# %% [markdown]
# ## Load data and create dataloaders
# ### You may need to edit MyDataset

# %%
class MyDataset(torch_dataset):
    def __init__(self, X, Y):
        self.X=X
        self.Y=Y
    def __len__(self):
        #return the number of data points
        return self.X.shape[0]
    def __getitem__(self, idx):        
        #we can use DatasetName[idx] to get a data point (x,y) with index idx
        x=torch.tensor(self.X[idx], dtype=torch.float32)
        y=torch.tensor(self.Y[idx], dtype=torch.int64)
        x=x.reshape(1,-1)
        return x, y

# %% [markdown]
# Attention: this dataset does not have class-imbalance issue.

# %%
import pandas as pd
X=pd.read_csv('ECG_dataX.csv')
Y=pd.read_csv('ECG_dataY.csv')

# %%
#convert dataframe to numpy array
X=X.values
X.shape
# Out:
# (3841, 187)

# %%
#convert dataframe to numpy array
Y=Y.values
Y.shape
# Out:
# (3841, 1)

# %%
#reshape Y into a 1D array
Y=Y.reshape(-1)
Y.shape
# Out:
# (3841,)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(Y)
# Out:
# (array([800.,   0., 800.,   0.,   0., 800.,   0., 641.,   0., 800.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
fs=125  # sampling frequency
Ts=1/fs # sampling interval
N=187 # the number of timepoints
Duration=N*Ts # duration of a signal
t=np.linspace(0, Duration-Ts, N) # array of timepoints
fig, ax = plt.subplots(5,1,constrained_layout=True, figsize=(10,10))
for c in range(0, 5):   
    for n in range(0, 3):
        idx=np.random.randint(0,10)
        ax[c].plot(t, X[Y==c][idx])        
        ax[c].set_xlabel('time t [seconds]', fontsize=16)
        ax[c].set_ylabel('amplitude', fontsize=16)
    ax[c].set_title('class '+str(c), fontsize=16)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=0)

# %%
dataset_train=MyDataset(X_train, Y_train)
dataset_val=MyDataset(X_val, Y_val)
dataset_test=MyDataset(X_test, Y_test)

# %%
loader_train = torch_dataloader(dataset_train, batch_size=128, shuffle=True, num_workers=0)
loader_val = torch_dataloader(dataset_val, batch_size=128, shuffle=False, num_workers=0) 
loader_test = torch_dataloader(dataset_test, batch_size=128, shuffle=False, num_workers=0)

# %% [markdown]
# ## Create a model, and start the traning-validation-testing process

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model=CNN()
model.to(device)
x=dataset_train[0][0]
x=x.view(1,1,187).to(device) #change it to x=x.view(1,1,187).to(device) for CNN
z=model(x)

# %%
y_hat=nnF.softmax(z, dim=1)
y_hat
# Out:
# tensor([[0.1751, 0.2198, 0.2035, 0.2006, 0.2010]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# use stochastic gradient descent as the optimization method

# %%
optimizer = optim.Adamax(model.parameters(), lr=0.001, weight_decay=1e-4)

# %%
loss_train_list=[]
acc_train_list=[]
acc_val_list=[]
epoch_save=-1

# %% [markdown]
# train/val/test over many epochs

# %%
for epoch in range(epoch_save+1, 100): #change 100 to a larger number if necessary
    #-------- training --------------------------------
    loss_train, acc_train =train(model, device, optimizer, loader_train, epoch)    
    loss_train_list.append(loss_train)
    acc_train_list.append(acc_train)
    print('epoch', epoch, 'training loss:', loss_train, 'acc:', acc_train)
    #-------- validation --------------------------------
    acc_val, other_val = test(model, device, loader_val)
    acc_val_list.append(acc_val)
    print('epoch', epoch, 'validation acc:', acc_val)
    #--------save model-------------------------
    result = (loss_train_list, acc_train_list, 
              acc_val_list, other_val)
    #change the name of the file if necessary, forgot to change the name so actual MLP is called real
    save_checkpoint('ECG_MLP_Pytorch_epoch'+str(epoch)+'.pt', model, optimizer, result, epoch)
    epoch_save=epoch
# Out:
# Train Epoch: 0 [0%]	Loss: 1.616278
# epoch 0 training loss: 0.781513047489253 acc: 0.7036903039073806
# epoch 0 validation acc: 0.19480519
# saved: ECG_MLP_Pytorch_epoch0.pt
# Train Epoch: 1 [0%]	Loss: 0.418574
# C:\Users\Nicko\AppData\Local\Temp\ipykernel_1128124\3076453557.py:13: RuntimeWarning: invalid value encountered in scalar divide
#   prec[n]=TP/(TP+FP)
# epoch 1 training loss: 0.459117282520641 acc: 0.8314037626628076
# epoch 1 validation acc: 0.53896105
# saved: ECG_MLP_Pytorch_epoch1.pt
# Train Epoch: 2 [0%]	Loss: 0.248237
# epoch 2 training loss: 0.34672491387887433 acc: 0.877713458755427
# epoch 2 validation acc: 0.7922078
# saved: ECG_MLP_Pytorch_epoch2.pt
# Train Epoch: 3 [0%]	Loss: 0.200459
# epoch 3 training loss: 0.28821093250404706 acc: 0.894356005788712
# epoch 3 validation acc: 0.83766234
# saved: ECG_MLP_Pytorch_epoch3.pt
# Train Epoch: 4 [0%]	Loss: 0.208726
# epoch 4 training loss: 0.25335400754755194 acc: 0.9095513748191028
# epoch 4 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch4.pt
# Train Epoch: 5 [0%]	Loss: 0.249277
# epoch 5 training loss: 0.21569407392631879 acc: 0.9258321273516642
# epoch 5 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch5.pt
# Train Epoch: 6 [0%]	Loss: 0.200049
# epoch 6 training loss: 0.1719774783334949 acc: 0.9442836468885673
# epoch 6 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch6.pt
# Train Epoch: 7 [0%]	Loss: 0.165406
# epoch 7 training loss: 0.15145997804674236 acc: 0.9518813314037626
# epoch 7 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch7.pt
# Train Epoch: 8 [0%]	Loss: 0.084862
# epoch 8 training loss: 0.13146260719407687 acc: 0.9569464544138929
# epoch 8 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch8.pt
# Train Epoch: 9 [0%]	Loss: 0.182577
# epoch 9 training loss: 0.11076566627757116 acc: 0.9645441389290883
# epoch 9 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch9.pt
# Train Epoch: 10 [0%]	Loss: 0.099282
# epoch 10 training loss: 0.09770177338610996 acc: 0.9717800289435601
# epoch 10 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch10.pt
# Train Epoch: 11 [0%]	Loss: 0.114181
# epoch 11 training loss: 0.08626045422120528 acc: 0.9732272069464544
# epoch 11 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch11.pt
# Train Epoch: 12 [0%]	Loss: 0.071645
# epoch 12 training loss: 0.0798111425882036 acc: 0.9757597684515196
# epoch 12 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch12.pt
# Train Epoch: 13 [0%]	Loss: 0.091457
# epoch 13 training loss: 0.06825362306765535 acc: 0.9808248914616498
# epoch 13 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch13.pt
# Train Epoch: 14 [0%]	Loss: 0.120616
# epoch 14 training loss: 0.05620440671389753 acc: 0.9880607814761215
# epoch 14 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch14.pt
# Train Epoch: 15 [0%]	Loss: 0.030200
# epoch 15 training loss: 0.048608456484296104 acc: 0.9873371924746743
# epoch 15 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch15.pt
# Train Epoch: 16 [0%]	Loss: 0.053054
# epoch 16 training loss: 0.04297994542866945 acc: 0.9887843704775687
# epoch 16 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch16.pt
# Train Epoch: 17 [0%]	Loss: 0.033605
# epoch 17 training loss: 0.033843617462976414 acc: 0.9916787264833574
# epoch 17 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch17.pt
# Train Epoch: 18 [0%]	Loss: 0.063835
# epoch 18 training loss: 0.03395196025005796 acc: 0.9927641099855282
# epoch 18 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch18.pt
# Train Epoch: 19 [0%]	Loss: 0.033982
# epoch 19 training loss: 0.03264631661163135 acc: 0.9927641099855282
# epoch 19 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch19.pt
# Train Epoch: 20 [0%]	Loss: 0.019349
# epoch 20 training loss: 0.02783119356767698 acc: 0.9931259044862518
# epoch 20 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch20.pt
# Train Epoch: 21 [0%]	Loss: 0.031107
# epoch 21 training loss: 0.03559437237510627 acc: 0.9895079594790159
# epoch 21 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch21.pt
# Train Epoch: 22 [0%]	Loss: 0.048836
# epoch 22 training loss: 0.031009775671091946 acc: 0.9913169319826338
# epoch 22 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch22.pt
# Train Epoch: 23 [0%]	Loss: 0.020785
# epoch 23 training loss: 0.024892730130390686 acc: 0.993849493487699
# epoch 23 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch23.pt
# Train Epoch: 24 [0%]	Loss: 0.007244
# epoch 24 training loss: 0.02453985899178819 acc: 0.9949348769898697
# epoch 24 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch24.pt
# Train Epoch: 25 [0%]	Loss: 0.016772
# epoch 25 training loss: 0.022779066814109683 acc: 0.9945730824891461
# epoch 25 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch25.pt
# Train Epoch: 26 [0%]	Loss: 0.006981
# epoch 26 training loss: 0.019450866236266764 acc: 0.9956584659913169
# epoch 26 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch26.pt
# Train Epoch: 27 [0%]	Loss: 0.012439
# epoch 27 training loss: 0.018633228769017893 acc: 0.9949348769898697
# epoch 27 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch27.pt
# Train Epoch: 28 [0%]	Loss: 0.013462
# epoch 28 training loss: 0.01577376686459915 acc: 0.9945730824891461
# epoch 28 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch28.pt
# Train Epoch: 29 [0%]	Loss: 0.006486
# epoch 29 training loss: 0.013995073693381115 acc: 0.9960202604920405
# epoch 29 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch29.pt
# Train Epoch: 30 [0%]	Loss: 0.009665
# epoch 30 training loss: 0.012841695813800801 acc: 0.9974674384949349
# epoch 30 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch30.pt
# Train Epoch: 31 [0%]	Loss: 0.008765
# epoch 31 training loss: 0.013876041683199053 acc: 0.9971056439942113
# epoch 31 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch31.pt
# Train Epoch: 32 [0%]	Loss: 0.013342
# epoch 32 training loss: 0.01567557284777815 acc: 0.9974674384949349
# epoch 32 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch32.pt
# Train Epoch: 33 [0%]	Loss: 0.019504
# epoch 33 training loss: 0.012014021059836854 acc: 0.9971056439942113
# epoch 33 validation acc: 0.9025974
# saved: ECG_MLP_Pytorch_epoch33.pt
# Train Epoch: 34 [0%]	Loss: 0.002807
# epoch 34 training loss: 0.008228011005981401 acc: 0.9989146164978292
# epoch 34 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch34.pt
# Train Epoch: 35 [0%]	Loss: 0.008864
# epoch 35 training loss: 0.013123333041386848 acc: 0.9967438494934877
# epoch 35 validation acc: 0.8701299
# saved: ECG_MLP_Pytorch_epoch35.pt
# Train Epoch: 36 [0%]	Loss: 0.006291
# epoch 36 training loss: 0.009646810876967555 acc: 0.998191027496382
# epoch 36 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch36.pt
# Train Epoch: 37 [0%]	Loss: 0.010292
# epoch 37 training loss: 0.011404769008301875 acc: 0.9985528219971056
# epoch 37 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch37.pt
# Train Epoch: 38 [0%]	Loss: 0.004333
# epoch 38 training loss: 0.010695522756908427 acc: 0.9978292329956585
# epoch 38 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch38.pt
# Train Epoch: 39 [0%]	Loss: 0.006783
# epoch 39 training loss: 0.011716872644187375 acc: 0.9978292329956585
# epoch 39 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch39.pt
# Train Epoch: 40 [0%]	Loss: 0.013266
# epoch 40 training loss: 0.006670681907880035 acc: 0.9989146164978292
# epoch 40 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch40.pt
# Train Epoch: 41 [0%]	Loss: 0.002165
# epoch 41 training loss: 0.00669640252916989 acc: 0.9985528219971056
# epoch 41 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch41.pt
# Train Epoch: 42 [0%]	Loss: 0.002600
# epoch 42 training loss: 0.007569347428877584 acc: 0.9989146164978292
# epoch 42 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch42.pt
# Train Epoch: 43 [0%]	Loss: 0.005816
# epoch 43 training loss: 0.009199064669453284 acc: 0.9974674384949349
# epoch 43 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch43.pt
# Train Epoch: 44 [0%]	Loss: 0.010681
# epoch 44 training loss: 0.020086672082966703 acc: 0.993849493487699
# epoch 44 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch44.pt
# Train Epoch: 45 [0%]	Loss: 0.034235
# epoch 45 training loss: 0.015505330679430203 acc: 0.9963820549927641
# epoch 45 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch45.pt
# Train Epoch: 46 [0%]	Loss: 0.007758
# epoch 46 training loss: 0.0125709611245177 acc: 0.9974674384949349
# epoch 46 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch46.pt
# Train Epoch: 47 [0%]	Loss: 0.006282
# epoch 47 training loss: 0.007269265013746917 acc: 0.9985528219971056
# epoch 47 validation acc: 0.9025974
# saved: ECG_MLP_Pytorch_epoch47.pt
# Train Epoch: 48 [0%]	Loss: 0.002823
# epoch 48 training loss: 0.0046821090138771315 acc: 0.9996382054992764
# epoch 48 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch48.pt
# Train Epoch: 49 [0%]	Loss: 0.018658
# epoch 49 training loss: 0.005780607536011798 acc: 0.998191027496382
# epoch 49 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch49.pt
# Train Epoch: 50 [0%]	Loss: 0.002610
# epoch 50 training loss: 0.002599612055663866 acc: 1.0
# epoch 50 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch50.pt
# Train Epoch: 51 [0%]	Loss: 0.007579
# epoch 51 training loss: 0.00515649986284023 acc: 0.9978292329956585
# epoch 51 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch51.pt
# Train Epoch: 52 [0%]	Loss: 0.001786
# epoch 52 training loss: 0.0036370938283983956 acc: 0.9996382054992764
# epoch 52 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch52.pt
# Train Epoch: 53 [0%]	Loss: 0.008386
# epoch 53 training loss: 0.0043843539368191905 acc: 0.9992764109985528
# epoch 53 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch53.pt
# Train Epoch: 54 [0%]	Loss: 0.002565
# epoch 54 training loss: 0.0023298048313749446 acc: 0.9996382054992764
# epoch 54 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch54.pt
# Train Epoch: 55 [0%]	Loss: 0.001320
# epoch 55 training loss: 0.0018631439200941134 acc: 1.0
# epoch 55 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch55.pt
# Train Epoch: 56 [0%]	Loss: 0.001784
# epoch 56 training loss: 0.0023786532930733465 acc: 0.9996382054992764
# epoch 56 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch56.pt
# Train Epoch: 57 [0%]	Loss: 0.001364
# epoch 57 training loss: 0.004108295090687038 acc: 0.9992764109985528
# epoch 57 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch57.pt
# Train Epoch: 58 [0%]	Loss: 0.001543
# epoch 58 training loss: 0.0072807813677090135 acc: 0.9974674384949349
# epoch 58 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch58.pt
# Train Epoch: 59 [0%]	Loss: 0.004969
# epoch 59 training loss: 0.01792258348061957 acc: 0.9952966714905933
# epoch 59 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch59.pt
# Train Epoch: 60 [0%]	Loss: 0.012392
# epoch 60 training loss: 0.013923637865280563 acc: 0.9960202604920405
# epoch 60 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch60.pt
# Train Epoch: 61 [0%]	Loss: 0.002654
# epoch 61 training loss: 0.014272453538565473 acc: 0.9963820549927641
# epoch 61 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch61.pt
# Train Epoch: 62 [0%]	Loss: 0.003154
# epoch 62 training loss: 0.017208817510188303 acc: 0.9960202604920405
# epoch 62 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch62.pt
# Train Epoch: 63 [0%]	Loss: 0.002085
# epoch 63 training loss: 0.008584608180998739 acc: 0.9978292329956585
# epoch 63 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch63.pt
# Train Epoch: 64 [0%]	Loss: 0.004118
# epoch 64 training loss: 0.007364966493861919 acc: 0.9978292329956585
# epoch 64 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch64.pt
# Train Epoch: 65 [0%]	Loss: 0.002984
# epoch 65 training loss: 0.004862113958965479 acc: 0.9985528219971056
# epoch 65 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch65.pt
# Train Epoch: 66 [0%]	Loss: 0.001701
# epoch 66 training loss: 0.004358689200175418 acc: 0.9992764109985528
# epoch 66 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch66.pt
# Train Epoch: 67 [0%]	Loss: 0.001274
# epoch 67 training loss: 0.002625030237885023 acc: 0.9996382054992764
# epoch 67 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch67.pt
# Train Epoch: 68 [0%]	Loss: 0.000545
# epoch 68 training loss: 0.0015343131539835172 acc: 1.0
# epoch 68 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch68.pt
# Train Epoch: 69 [0%]	Loss: 0.000610
# epoch 69 training loss: 0.0014115018288562583 acc: 1.0
# epoch 69 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch69.pt
# Train Epoch: 70 [0%]	Loss: 0.000933
# epoch 70 training loss: 0.0011578476498305629 acc: 1.0
# epoch 70 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch70.pt
# Train Epoch: 71 [0%]	Loss: 0.000801
# epoch 71 training loss: 0.0010301951485664838 acc: 1.0
# epoch 71 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch71.pt
# Train Epoch: 72 [0%]	Loss: 0.001256
# epoch 72 training loss: 0.0011283927134090018 acc: 1.0
# epoch 72 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch72.pt
# Train Epoch: 73 [0%]	Loss: 0.000775
# epoch 73 training loss: 0.0009454622459915382 acc: 1.0
# epoch 73 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch73.pt
# Train Epoch: 74 [0%]	Loss: 0.001694
# epoch 74 training loss: 0.001004548350465484 acc: 1.0
# epoch 74 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch74.pt
# Train Epoch: 75 [0%]	Loss: 0.001220
# epoch 75 training loss: 0.0008735298033570871 acc: 1.0
# epoch 75 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch75.pt
# Train Epoch: 76 [0%]	Loss: 0.000654
# epoch 76 training loss: 0.0007714587012411688 acc: 1.0
# epoch 76 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch76.pt
# Train Epoch: 77 [0%]	Loss: 0.001117
# epoch 77 training loss: 0.0008609798387624323 acc: 1.0
# epoch 77 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch77.pt
# Train Epoch: 78 [0%]	Loss: 0.001372
# epoch 78 training loss: 0.000878912167867053 acc: 1.0
# epoch 78 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch78.pt
# Train Epoch: 79 [0%]	Loss: 0.001544
# epoch 79 training loss: 0.0009421503345947713 acc: 1.0
# epoch 79 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch79.pt
# Train Epoch: 80 [0%]	Loss: 0.000933
# epoch 80 training loss: 0.0008445241004334424 acc: 1.0
# epoch 80 validation acc: 0.9025974
# saved: ECG_MLP_Pytorch_epoch80.pt
# Train Epoch: 81 [0%]	Loss: 0.001103
# epoch 81 training loss: 0.000972035994478078 acc: 1.0
# epoch 81 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch81.pt
# Train Epoch: 82 [0%]	Loss: 0.000501
# epoch 82 training loss: 0.0008236515674401413 acc: 1.0
# epoch 82 validation acc: 0.9025974
# saved: ECG_MLP_Pytorch_epoch82.pt
# Train Epoch: 83 [0%]	Loss: 0.000515
# epoch 83 training loss: 0.0009974319241750477 acc: 1.0
# epoch 83 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch83.pt
# Train Epoch: 84 [0%]	Loss: 0.000815
# epoch 84 training loss: 0.00198600292655597 acc: 0.9992764109985528
# epoch 84 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch84.pt
# Train Epoch: 85 [0%]	Loss: 0.000647
# epoch 85 training loss: 0.006193127446088262 acc: 0.998191027496382
# epoch 85 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch85.pt
# Train Epoch: 86 [0%]	Loss: 0.001857
# epoch 86 training loss: 0.0069845907432450486 acc: 0.998191027496382
# epoch 86 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch86.pt
# Train Epoch: 87 [0%]	Loss: 0.025816
# epoch 87 training loss: 0.006276207211406224 acc: 0.9985528219971056
# epoch 87 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch87.pt
# Train Epoch: 88 [0%]	Loss: 0.007102
# epoch 88 training loss: 0.00544135142329403 acc: 0.9989146164978292
# epoch 88 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch88.pt
# Train Epoch: 89 [0%]	Loss: 0.000628
# epoch 89 training loss: 0.008197175278010864 acc: 0.9967438494934877
# epoch 89 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch89.pt
# Train Epoch: 90 [0%]	Loss: 0.003480
# epoch 90 training loss: 0.004946108230135657 acc: 0.9996382054992764
# epoch 90 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch90.pt
# Train Epoch: 91 [0%]	Loss: 0.003137
# epoch 91 training loss: 0.003000979369971901 acc: 0.9992764109985528
# epoch 91 validation acc: 0.9025974
# saved: ECG_MLP_Pytorch_epoch91.pt
# Train Epoch: 92 [0%]	Loss: 0.003180
# epoch 92 training loss: 0.0027135668642586097 acc: 0.9996382054992764
# epoch 92 validation acc: 0.8961039
# saved: ECG_MLP_Pytorch_epoch92.pt
# Train Epoch: 93 [0%]	Loss: 0.001818
# epoch 93 training loss: 0.0017744541850830005 acc: 1.0
# epoch 93 validation acc: 0.90584415
# saved: ECG_MLP_Pytorch_epoch93.pt
# Train Epoch: 94 [0%]	Loss: 0.001765
# epoch 94 training loss: 0.0011242838782808658 acc: 1.0
# epoch 94 validation acc: 0.9025974
# saved: ECG_MLP_Pytorch_epoch94.pt
# Train Epoch: 95 [0%]	Loss: 0.000349
# epoch 95 training loss: 0.0009199646433857693 acc: 1.0
# epoch 95 validation acc: 0.9025974
# saved: ECG_MLP_Pytorch_epoch95.pt
# Train Epoch: 96 [0%]	Loss: 0.002078
# epoch 96 training loss: 0.0006661061290122399 acc: 1.0
# epoch 96 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch96.pt
# Train Epoch: 97 [0%]	Loss: 0.000504
# epoch 97 training loss: 0.0005507803765464236 acc: 1.0
# epoch 97 validation acc: 0.89935064
# saved: ECG_MLP_Pytorch_epoch97.pt
# Train Epoch: 98 [0%]	Loss: 0.000205
# epoch 98 training loss: 0.0005510990899479525 acc: 1.0
# epoch 98 validation acc: 0.9025974
# saved: ECG_MLP_Pytorch_epoch98.pt
# Train Epoch: 99 [0%]	Loss: 0.000631
# epoch 99 training loss: 0.0005287194098028439 acc: 1.0
# epoch 99 validation acc: 0.9025974
# saved: ECG_MLP_Pytorch_epoch99.pt

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].set_title('loss v.s. epoch',fontsize=16)
ax[0].plot(loss_train_list, '-b', label='training loss')
ax[0].set_xlabel('epoch',fontsize=16)
ax[0].legend(fontsize=16)
ax[0].grid(True)
ax[1].set_title('accuracy v.s. epoch',fontsize=16)
ax[1].plot(acc_train_list, '-b', label='training accuracy')
ax[1].plot(acc_val_list, '-g', label='validation accuracy')
ax[1].set_xlabel('epoch',fontsize=16)
ax[1].legend(fontsize=16)
ax[1].grid(True)

# %% [markdown]
# load the best model

# %%
best_epoch=np.argmax(acc_val_list)
best_epoch
# Out:
# 93

# %%
checkpoint=torch.load('ECG_MLP_Pytorch_epoch'+str(best_epoch)+'.pt')
model=CNN()
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device);
model.eval();

# %%
acc, (confusion, sens, prec) = test(model, device, loader_test)
print('Accuracy (average)', acc)
print('Sensitivity', sens)
print('Precision', prec)
print('Confusion \n', confusion)
# Out:
# Accuracy (average) 0.92717814
# Sensitivity [0.88068181 0.92207789 0.91780823 0.95901638 0.9649123 ]
# Precision [0.89595377 0.88749999 0.96402878 0.90697676 0.98214287]
# Confusion
#  [[155.  14.   2.   4.   1.]
#  [ 10. 142.   1.   1.   0.]
#  [  3.   1. 134.   6.   2.]
#  [  4.   1.   0. 117.   0.]
#  [  1.   2.   2.   1. 165.]]
